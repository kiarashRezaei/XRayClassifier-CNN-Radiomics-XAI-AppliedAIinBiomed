# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import sklearn as skl
import sklearn.model_selection as skl_ms
import seaborn as sns
import cv2
from PIL import Image
import tensorflow_addons as tfa

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

tfk = tf.keras
tfkl = tf.keras.layers

# %%
dataframe = pd.read_csv('/kaggle/input/quality-annotated-dataframe/quality_annotated_dataframe.csv')

# %%
dataframe_quality = dataframe[dataframe['quality'] == 0]

filenames = dataframe_quality['file'].to_numpy()
to_remove = np.zeros(filenames.shape[0])

num_duplicates = 0

# Let's remove duplicates
for index in range(filenames.shape[0]):
    # Ignore the last element
    if index == filenames.shape[0] - 1:
        break
    
    filename = filenames[index]
    next_filename = filenames[index + 1]
    
    # Remove extension
    filename = filename.replace('.png', '')
    filename = filename.replace('.jpeg', '')
    next_filename = next_filename.replace('.png', '')
    next_filename = next_filename.replace('.jpeg', '')
    
    # If consecutive filenames refer to the same patient
    if filename[:-2] == next_filename[:-2]:
        to_remove[index + 1] = 1
        num_duplicates = num_duplicates + 1
        index = index + 1
        
dataframe_quality = dataframe_quality[to_remove == 0]
        
print('Removed %d duplicates' % num_duplicates)

dataframe_path = dataframe_quality.copy()
dataframe_path['path'] = '/kaggle/input/training-dataset/train/' + dataframe_path['label'] + '/' + dataframe_path['file']
# Out:
# Removed 1293 duplicates

# %%
labels = dataframe_path['label']

# Create a bar plot
plt.bar(np.unique(labels), [np.sum(labels == l) for l in np.unique(labels)])

# Add labels and title to the plot
plt.xlabel('Class Labels')
plt.ylabel('Class Counts')
plt.title('Class Distribution of Quality images')

# Display the plot
plt.show()

# %%
seed = 3913326
#seed = 451857256
train_path_based, test_path_based = train_test_split(dataframe_path,random_state = seed, test_size=0.2, shuffle=True)
train_path_based, validation_path_based = train_test_split(train_path_based, random_state=seed, test_size=0.1, shuffle=True)

# %%
#for aug
def preprocessing(image):
    if image.shape[-1] == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    image = np.uint8(image)

    # Check if background is Standard Radiological Format compliant, otherwise invert colors
    # (the check is performed on the median color along the spine)
    buffer = image / np.max(image)

    median_spine = np.median(buffer[:, buffer.shape[1] // 2])

    if median_spine < 0.5:
        image = cv2.bitwise_not(image)

    # Mist reduction and gamma transformation
    img_equalized = cv2.equalizeHist(image)
    gamma = 1.5
    inv_gamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** inv_gamma) * 255
                    for i in np.arange(0, 256)]).astype('uint8')
    img_gamma = cv2.LUT(img_equalized, table)

    # Apply Adaptive Contrast Equalization
    clahe = cv2.createCLAHE(clipLimit=40.0, tileGridSize=(8,8))
    clahe_img = clahe.apply(img_gamma)

    # Apply Gaussian Smoothing
    gaussian_img = cv2.GaussianBlur(clahe_img, (5,5), 0)
    gaussian_img = gaussian_img.reshape((512,512,1))
    
    return gaussian_img

# %%
#for aug
root_dir = '/kaggle/input/normalpneumoniatubeculosis-qualityannotated'

train_datagen = ImageDataGenerator(preprocessing_function=preprocessing)
# Use flow_from_dataframe method to read images from directory based on dataframe
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_path_based,
    directory=root_dir,
    x_col='path',
    y_col='label',
    target_size=(512, 512), # set the target image size
    batch_size=64, # set the batch size
    data_format="channels_last",
    color_mode='grayscale',
    class_mode='categorical' # set the class mode to categorical for multi-class classification
)


validation_datagen = ImageDataGenerator(preprocessing_function=preprocessing)

# Use flow_from_dataframe method to read images from directory based on dataframe
validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=validation_path_based,
    directory=root_dir,
    x_col='path',
    y_col='label',
    shuffle = False,
    target_size=(512, 512), # set the target image size
    batch_size=64, # set the batch size
    data_format="channels_last",
    color_mode='grayscale',
    class_mode='categorical' # set the class mode to categorical for multi-class classification
)


test_datagen = ImageDataGenerator(preprocessing_function=preprocessing)

# Use flow_from_dataframe method to read images from directory based on dataframe
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_path_based,
    directory=root_dir,
    x_col='path',
    y_col='label',
    shuffle = False,
    target_size=(512, 512), # set the target image size
    batch_size=64, # set the batch size
    data_format="channels_last",
    color_mode='grayscale',
    class_mode='categorical' # set the class mode to categorical for multi-class classification
)
# Out:
# Found 7769 validated image filenames belonging to 3 classes.
# Found 864 validated image filenames belonging to 3 classes.
# Found 2159 validated image filenames belonging to 3 classes.

# %%
pretrained_model = tfk.applications.DenseNet169(
    input_shape=(512,512,3),
    include_top=False,
    weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step

# %%
for i, layer in enumerate(pretrained_model.layers):
    print(f'{i} - {layer.name}')
# Out:
# 0 - input_1
# 1 - zero_padding2d
# 2 - conv1/conv
# 3 - conv1/bn
# 4 - conv1/relu
# 5 - zero_padding2d_1
# 6 - pool1
# 7 - conv2_block1_0_bn
# 8 - conv2_block1_0_relu
# 9 - conv2_block1_1_conv
# 10 - conv2_block1_1_bn
# 11 - conv2_block1_1_relu
# 12 - conv2_block1_2_conv
# 13 - conv2_block1_concat
# 14 - conv2_block2_0_bn
# 15 - conv2_block2_0_relu
# 16 - conv2_block2_1_conv
# 17 - conv2_block2_1_bn
# 18 - conv2_block2_1_relu
# 19 - conv2_block2_2_conv
# 20 - conv2_block2_concat
# 21 - conv2_block3_0_bn
# 22 - conv2_block3_0_relu
# 23 - conv2_block3_1_conv
# 24 - conv2_block3_1_bn
# 25 - conv2_block3_1_relu
# 26 - conv2_block3_2_conv
# 27 - conv2_block3_concat
# 28 - conv2_block4_0_bn
# 29 - conv2_block4_0_relu
# 30 - conv2_block4_1_conv
# 31 - conv2_block4_1_bn
# 32 - conv2_block4_1_relu
# 33 - conv2_block4_2_conv
# 34 - conv2_block4_concat
# 35 - conv2_block5_0_bn
# 36 - conv2_block5_0_relu
# 37 - conv2_block5_1_conv
# 38 - conv2_block5_1_bn
# 39 - conv2_block5_1_relu
# 40 - conv2_block5_2_conv
# 41 - conv2_block5_concat
# 42 - conv2_block6_0_bn
# 43 - conv2_block6_0_relu
# 44 - conv2_block6_1_conv
# 45 - conv2_block6_1_bn
# 46 - conv2_block6_1_relu
# 47 - conv2_block6_2_conv
# 48 - conv2_block6_concat
# 49 - pool2_bn
# 50 - pool2_relu
# 51 - pool2_conv
# 52 - pool2_pool
# 53 - conv3_block1_0_bn
# 54 - conv3_block1_0_relu
# 55 - conv3_block1_1_conv
# 56 - conv3_block1_1_bn
# 57 - conv3_block1_1_relu
# 58 - conv3_block1_2_conv
# 59 - conv3_block1_concat
# 60 - conv3_block2_0_bn
# 61 - conv3_block2_0_relu
# 62 - conv3_block2_1_conv
# 63 - conv3_block2_1_bn
# 64 - conv3_block2_1_relu
# 65 - conv3_block2_2_conv
# 66 - conv3_block2_concat
# 67 - conv3_block3_0_bn
# 68 - conv3_block3_0_relu
# 69 - conv3_block3_1_conv
# 70 - conv3_block3_1_bn
# 71 - conv3_block3_1_relu
# 72 - conv3_block3_2_conv
# 73 - conv3_block3_concat
# 74 - conv3_block4_0_bn
# 75 - conv3_block4_0_relu
# 76 - conv3_block4_1_conv
# 77 - conv3_block4_1_bn
# 78 - conv3_block4_1_relu
# 79 - conv3_block4_2_conv
# 80 - conv3_block4_concat
# 81 - conv3_block5_0_bn
# 82 - conv3_block5_0_relu
# 83 - conv3_block5_1_conv
# 84 - conv3_block5_1_bn
# 85 - conv3_block5_1_relu
# 86 - conv3_block5_2_conv
# 87 - conv3_block5_concat
# 88 - conv3_block6_0_bn
# 89 - conv3_block6_0_relu
# 90 - conv3_block6_1_conv
# 91 - conv3_block6_1_bn
# 92 - conv3_block6_1_relu
# 93 - conv3_block6_2_conv
# 94 - conv3_block6_concat
# 95 - conv3_block7_0_bn
# 96 - conv3_block7_0_relu
# 97 - conv3_block7_1_conv
# 98 - conv3_block7_1_bn
# 99 - conv3_block7_1_relu
# 100 - conv3_block7_2_conv
# 101 - conv3_block7_concat
# 102 - conv3_block8_0_bn
# 103 - conv3_block8_0_relu
# 104 - conv3_block8_1_conv
# 105 - conv3_block8_1_bn
# 106 - conv3_block8_1_relu
# 107 - conv3_block8_2_conv
# 108 - conv3_block8_concat
# 109 - conv3_block9_0_bn
# 110 - conv3_block9_0_relu
# 111 - conv3_block9_1_conv
# 112 - conv3_block9_1_bn
# 113 - conv3_block9_1_relu
# 114 - conv3_block9_2_conv
# 115 - conv3_block9_concat
# 116 - conv3_block10_0_bn
# 117 - conv3_block10_0_relu
# 118 - conv3_block10_1_conv
# 119 - conv3_block10_1_bn
# 120 - conv3_block10_1_relu
# 121 - conv3_block10_2_conv
# 122 - conv3_block10_concat
# 123 - conv3_block11_0_bn
# 124 - conv3_block11_0_relu
# 125 - conv3_block11_1_conv
# 126 - conv3_block11_1_bn
# 127 - conv3_block11_1_relu
# 128 - conv3_block11_2_conv
# 129 - conv3_block11_concat
# 130 - conv3_block12_0_bn
# 131 - conv3_block12_0_relu
# 132 - conv3_block12_1_conv
# 133 - conv3_block12_1_bn
# 134 - conv3_block12_1_relu
# 135 - conv3_block12_2_conv
# 136 - conv3_block12_concat
# 137 - pool3_bn
# 138 - pool3_relu
# 139 - pool3_conv
# 140 - pool3_pool
# 141 - conv4_block1_0_bn
# 142 - conv4_block1_0_relu
# 143 - conv4_block1_1_conv
# 144 - conv4_block1_1_bn
# 145 - conv4_block1_1_relu
# 146 - conv4_block1_2_conv
# 147 - conv4_block1_concat
# 148 - conv4_block2_0_bn
# 149 - conv4_block2_0_relu
# 150 - conv4_block2_1_conv
# 151 - conv4_block2_1_bn
# 152 - conv4_block2_1_relu
# 153 - conv4_block2_2_conv
# 154 - conv4_block2_concat
# 155 - conv4_block3_0_bn
# 156 - conv4_block3_0_relu
# 157 - conv4_block3_1_conv
# 158 - conv4_block3_1_bn
# 159 - conv4_block3_1_relu
# 160 - conv4_block3_2_conv
# 161 - conv4_block3_concat
# 162 - conv4_block4_0_bn
# 163 - conv4_block4_0_relu
# 164 - conv4_block4_1_conv
# 165 - conv4_block4_1_bn
# 166 - conv4_block4_1_relu
# 167 - conv4_block4_2_conv
# 168 - conv4_block4_concat
# 169 - conv4_block5_0_bn
# 170 - conv4_block5_0_relu
# 171 - conv4_block5_1_conv
# 172 - conv4_block5_1_bn
# 173 - conv4_block5_1_relu
# 174 - conv4_block5_2_conv
# 175 - conv4_block5_concat
# 176 - conv4_block6_0_bn
# 177 - conv4_block6_0_relu
# 178 - conv4_block6_1_conv
# 179 - conv4_block6_1_bn
# 180 - conv4_block6_1_relu
# 181 - conv4_block6_2_conv
# 182 - conv4_block6_concat
# 183 - conv4_block7_0_bn
# 184 - conv4_block7_0_relu
# 185 - conv4_block7_1_conv
# 186 - conv4_block7_1_bn
# 187 - conv4_block7_1_relu
# 188 - conv4_block7_2_conv
# 189 - conv4_block7_concat
# 190 - conv4_block8_0_bn
# 191 - conv4_block8_0_relu
# 192 - conv4_block8_1_conv
# 193 - conv4_block8_1_bn
# 194 - conv4_block8_1_relu
# 195 - conv4_block8_2_conv
# 196 - conv4_block8_concat
# 197 - conv4_block9_0_bn
# 198 - conv4_block9_0_relu
# 199 - conv4_block9_1_conv
# 200 - conv4_block9_1_bn
# 201 - conv4_block9_1_relu
# 202 - conv4_block9_2_conv
# 203 - conv4_block9_concat
# 204 - conv4_block10_0_bn
# 205 - conv4_block10_0_relu
# 206 - conv4_block10_1_conv
# 207 - conv4_block10_1_bn
# 208 - conv4_block10_1_relu
# 209 - conv4_block10_2_conv
# 210 - conv4_block10_concat
# 211 - conv4_block11_0_bn
# 212 - conv4_block11_0_relu
# 213 - conv4_block11_1_conv
# 214 - conv4_block11_1_bn
# 215 - conv4_block11_1_relu
# 216 - conv4_block11_2_conv
# 217 - conv4_block11_concat
# 218 - conv4_block12_0_bn
# 219 - conv4_block12_0_relu
# 220 - conv4_block12_1_conv
# 221 - conv4_block12_1_bn
# 222 - conv4_block12_1_relu
# 223 - conv4_block12_2_conv
# 224 - conv4_block12_concat
# 225 - conv4_block13_0_bn
# 226 - conv4_block13_0_relu
# 227 - conv4_block13_1_conv
# 228 - conv4_block13_1_bn
# 229 - conv4_block13_1_relu
# 230 - conv4_block13_2_conv
# 231 - conv4_block13_concat
# 232 - conv4_block14_0_bn
# 233 - conv4_block14_0_relu
# 234 - conv4_block14_1_conv
# 235 - conv4_block14_1_bn
# 236 - conv4_block14_1_relu
# 237 - conv4_block14_2_conv
# 238 - conv4_block14_concat
# 239 - conv4_block15_0_bn
# 240 - conv4_block15_0_relu
# 241 - conv4_block15_1_conv
# 242 - conv4_block15_1_bn
# 243 - conv4_block15_1_relu
# 244 - conv4_block15_2_conv
# 245 - conv4_block15_concat
# 246 - conv4_block16_0_bn
# 247 - conv4_block16_0_relu
# 248 - conv4_block16_1_conv
# 249 - conv4_block16_1_bn
# 250 - conv4_block16_1_relu
# 251 - conv4_block16_2_conv
# 252 - conv4_block16_concat
# 253 - conv4_block17_0_bn
# 254 - conv4_block17_0_relu
# 255 - conv4_block17_1_conv
# 256 - conv4_block17_1_bn
# 257 - conv4_block17_1_relu
# 258 - conv4_block17_2_conv
# 259 - conv4_block17_concat
# 260 - conv4_block18_0_bn
# 261 - conv4_block18_0_relu
# 262 - conv4_block18_1_conv
# 263 - conv4_block18_1_bn
# 264 - conv4_block18_1_relu
# 265 - conv4_block18_2_conv
# 266 - conv4_block18_concat
# 267 - conv4_block19_0_bn
# 268 - conv4_block19_0_relu
# 269 - conv4_block19_1_conv
# 270 - conv4_block19_1_bn
# 271 - conv4_block19_1_relu
# 272 - conv4_block19_2_conv
# 273 - conv4_block19_concat
# 274 - conv4_block20_0_bn
# 275 - conv4_block20_0_relu
# 276 - conv4_block20_1_conv
# 277 - conv4_block20_1_bn
# 278 - conv4_block20_1_relu
# 279 - conv4_block20_2_conv
# 280 - conv4_block20_concat
# 281 - conv4_block21_0_bn
# 282 - conv4_block21_0_relu
# 283 - conv4_block21_1_conv
# 284 - conv4_block21_1_bn
# 285 - conv4_block21_1_relu
# 286 - conv4_block21_2_conv
# 287 - conv4_block21_concat
# 288 - conv4_block22_0_bn
# 289 - conv4_block22_0_relu
# 290 - conv4_block22_1_conv
# 291 - conv4_block22_1_bn
# 292 - conv4_block22_1_relu
# 293 - conv4_block22_2_conv
# 294 - conv4_block22_concat
# 295 - conv4_block23_0_bn
# 296 - conv4_block23_0_relu
# 297 - conv4_block23_1_conv
# 298 - conv4_block23_1_bn
# 299 - conv4_block23_1_relu
# 300 - conv4_block23_2_conv
# 301 - conv4_block23_concat
# 302 - conv4_block24_0_bn
# 303 - conv4_block24_0_relu
# 304 - conv4_block24_1_conv
# 305 - conv4_block24_1_bn
# 306 - conv4_block24_1_relu
# 307 - conv4_block24_2_conv
# 308 - conv4_block24_concat
# 309 - conv4_block25_0_bn
# 310 - conv4_block25_0_relu
# 311 - conv4_block25_1_conv
# 312 - conv4_block25_1_bn
# 313 - conv4_block25_1_relu
# 314 - conv4_block25_2_conv
# 315 - conv4_block25_concat
# 316 - conv4_block26_0_bn
# 317 - conv4_block26_0_relu
# 318 - conv4_block26_1_conv
# 319 - conv4_block26_1_bn
# 320 - conv4_block26_1_relu
# 321 - conv4_block26_2_conv
# 322 - conv4_block26_concat
# 323 - conv4_block27_0_bn
# 324 - conv4_block27_0_relu
# 325 - conv4_block27_1_conv
# 326 - conv4_block27_1_bn
# 327 - conv4_block27_1_relu
# 328 - conv4_block27_2_conv
# 329 - conv4_block27_concat
# 330 - conv4_block28_0_bn
# 331 - conv4_block28_0_relu
# 332 - conv4_block28_1_conv
# 333 - conv4_block28_1_bn
# 334 - conv4_block28_1_relu
# 335 - conv4_block28_2_conv
# 336 - conv4_block28_concat
# 337 - conv4_block29_0_bn
# 338 - conv4_block29_0_relu
# 339 - conv4_block29_1_conv
# 340 - conv4_block29_1_bn
# 341 - conv4_block29_1_relu
# 342 - conv4_block29_2_conv
# 343 - conv4_block29_concat
# 344 - conv4_block30_0_bn
# 345 - conv4_block30_0_relu
# 346 - conv4_block30_1_conv
# 347 - conv4_block30_1_bn
# 348 - conv4_block30_1_relu
# 349 - conv4_block30_2_conv
# 350 - conv4_block30_concat
# 351 - conv4_block31_0_bn
# 352 - conv4_block31_0_relu
# 353 - conv4_block31_1_conv
# 354 - conv4_block31_1_bn
# 355 - conv4_block31_1_relu
# 356 - conv4_block31_2_conv
# 357 - conv4_block31_concat
# 358 - conv4_block32_0_bn
# 359 - conv4_block32_0_relu
# 360 - conv4_block32_1_conv
# 361 - conv4_block32_1_bn
# 362 - conv4_block32_1_relu
# 363 - conv4_block32_2_conv
# 364 - conv4_block32_concat
# 365 - pool4_bn
# 366 - pool4_relu
# 367 - pool4_conv
# 368 - pool4_pool
# 369 - conv5_block1_0_bn
# 370 - conv5_block1_0_relu
# 371 - conv5_block1_1_conv
# 372 - conv5_block1_1_bn
# 373 - conv5_block1_1_relu
# 374 - conv5_block1_2_conv
# 375 - conv5_block1_concat
# 376 - conv5_block2_0_bn
# 377 - conv5_block2_0_relu
# 378 - conv5_block2_1_conv
# 379 - conv5_block2_1_bn
# 380 - conv5_block2_1_relu
# 381 - conv5_block2_2_conv
# 382 - conv5_block2_concat
# 383 - conv5_block3_0_bn
# 384 - conv5_block3_0_relu
# 385 - conv5_block3_1_conv
# 386 - conv5_block3_1_bn
# 387 - conv5_block3_1_relu
# 388 - conv5_block3_2_conv
# 389 - conv5_block3_concat
# 390 - conv5_block4_0_bn
# 391 - conv5_block4_0_relu
# 392 - conv5_block4_1_conv
# 393 - conv5_block4_1_bn
# 394 - conv5_block4_1_relu
# 395 - conv5_block4_2_conv
# 396 - conv5_block4_concat
# 397 - conv5_block5_0_bn
# 398 - conv5_block5_0_relu
# 399 - conv5_block5_1_conv
# 400 - conv5_block5_1_bn
# 401 - conv5_block5_1_relu
# 402 - conv5_block5_2_conv
# 403 - conv5_block5_concat
# 404 - conv5_block6_0_bn
# 405 - conv5_block6_0_relu
# 406 - conv5_block6_1_conv
# 407 - conv5_block6_1_bn
# 408 - conv5_block6_1_relu
# 409 - conv5_block6_2_conv
# 410 - conv5_block6_concat
# 411 - conv5_block7_0_bn
# 412 - conv5_block7_0_relu
# 413 - conv5_block7_1_conv
# 414 - conv5_block7_1_bn
# 415 - conv5_block7_1_relu
# 416 - conv5_block7_2_conv
# 417 - conv5_block7_concat
# 418 - conv5_block8_0_bn
# 419 - conv5_block8_0_relu
# 420 - conv5_block8_1_conv
# 421 - conv5_block8_1_bn
# 422 - conv5_block8_1_relu
# 423 - conv5_block8_2_conv
# 424 - conv5_block8_concat
# 425 - conv5_block9_0_bn
# 426 - conv5_block9_0_relu
# 427 - conv5_block9_1_conv
# 428 - conv5_block9_1_bn
# 429 - conv5_block9_1_relu
# 430 - conv5_block9_2_conv
# 431 - conv5_block9_concat
# 432 - conv5_block10_0_bn
# 433 - conv5_block10_0_relu
# 434 - conv5_block10_1_conv
# 435 - conv5_block10_1_bn
# 436 - conv5_block10_1_relu
# 437 - conv5_block10_2_conv
# 438 - conv5_block10_concat
# 439 - conv5_block11_0_bn
# 440 - conv5_block11_0_relu
# 441 - conv5_block11_1_conv
# 442 - conv5_block11_1_bn
# 443 - conv5_block11_1_relu
# 444 - conv5_block11_2_conv
# 445 - conv5_block11_concat
# 446 - conv5_block12_0_bn
# 447 - conv5_block12_0_relu
# 448 - conv5_block12_1_conv
# 449 - conv5_block12_1_bn
# 450 - conv5_block12_1_relu
# 451 - conv5_block12_2_conv
# 452 - conv5_block12_concat
# 453 - conv5_block13_0_bn
# 454 - conv5_block13_0_relu
# 455 - conv5_block13_1_conv
# 456 - conv5_block13_1_bn
# 457 - conv5_block13_1_relu
# 458 - conv5_block13_2_conv
# 459 - conv5_block13_concat
# 460 - conv5_block14_0_bn
# 461 - conv5_block14_0_relu
# 462 - conv5_block14_1_conv
# 463 - conv5_block14_1_bn
# 464 - conv5_block14_1_relu
# 465 - conv5_block14_2_conv
# 466 - conv5_block14_concat
# 467 - conv5_block15_0_bn
# 468 - conv5_block15_0_relu
# 469 - conv5_block15_1_conv
# 470 - conv5_block15_1_bn
# 471 - conv5_block15_1_relu
# 472 - conv5_block15_2_conv
# 473 - conv5_block15_concat
# 474 - conv5_block16_0_bn
# 475 - conv5_block16_0_relu
# 476 - conv5_block16_1_conv
# 477 - conv5_block16_1_bn
# 478 - conv5_block16_1_relu
# 479 - conv5_block16_2_conv
# 480 - conv5_block16_concat
# 481 - conv5_block17_0_bn
# 482 - conv5_block17_0_relu
# 483 - conv5_block17_1_conv
# 484 - conv5_block17_1_bn
# 485 - conv5_block17_1_relu
# 486 - conv5_block17_2_conv
# 487 - conv5_block17_concat
# 488 - conv5_block18_0_bn
# 489 - conv5_block18_0_relu
# 490 - conv5_block18_1_conv
# 491 - conv5_block18_1_bn
# 492 - conv5_block18_1_relu
# 493 - conv5_block18_2_conv
# 494 - conv5_block18_concat
# 495 - conv5_block19_0_bn
# 496 - conv5_block19_0_relu
# 497 - conv5_block19_1_conv
# 498 - conv5_block19_1_bn
# 499 - conv5_block19_1_relu
# 500 - conv5_block19_2_conv
# 501 - conv5_block19_concat
# 502 - conv5_block20_0_bn
# 503 - conv5_block20_0_relu
# 504 - conv5_block20_1_conv
# 505 - conv5_block20_1_bn
# 506 - conv5_block20_1_relu
# 507 - conv5_block20_2_conv
# 508 - conv5_block20_concat
# 509 - conv5_block21_0_bn
# 510 - conv5_block21_0_relu
# 511 - conv5_block21_1_conv
# 512 - conv5_block21_1_bn
# 513 - conv5_block21_1_relu
# 514 - conv5_block21_2_conv
# 515 - conv5_block21_concat
# 516 - conv5_block22_0_bn
# 517 - conv5_block22_0_relu
# 518 - conv5_block22_1_conv
# 519 - conv5_block22_1_bn
# 520 - conv5_block22_1_relu
# 521 - conv5_block22_2_conv
# 522 - conv5_block22_concat
# 523 - conv5_block23_0_bn
# 524 - conv5_block23_0_relu
# 525 - conv5_block23_1_conv
# 526 - conv5_block23_1_bn
# 527 - conv5_block23_1_relu
# 528 - conv5_block23_2_conv
# 529 - conv5_block23_concat
# 530 - conv5_block24_0_bn
# 531 - conv5_block24_0_relu
# 532 - conv5_block24_1_conv
# 533 - conv5_block24_1_bn
# 534 - conv5_block24_1_relu
# 535 - conv5_block24_2_conv
# 536 - conv5_block24_concat
# 537 - conv5_block25_0_bn
# 538 - conv5_block25_0_relu
# 539 - conv5_block25_1_conv
# 540 - conv5_block25_1_bn
# 541 - conv5_block25_1_relu
# 542 - conv5_block25_2_conv
# 543 - conv5_block25_concat
# 544 - conv5_block26_0_bn
# 545 - conv5_block26_0_relu
# 546 - conv5_block26_1_conv
# 547 - conv5_block26_1_bn
# 548 - conv5_block26_1_relu
# 549 - conv5_block26_2_conv
# 550 - conv5_block26_concat
# 551 - conv5_block27_0_bn
# 552 - conv5_block27_0_relu
# 553 - conv5_block27_1_conv
# 554 - conv5_block27_1_bn
# 555 - conv5_block27_1_relu
# 556 - conv5_block27_2_conv
# 557 - conv5_block27_concat
# 558 - conv5_block28_0_bn
# 559 - conv5_block28_0_relu
# 560 - conv5_block28_1_conv
# 561 - conv5_block28_1_bn
# 562 - conv5_block28_1_relu
# 563 - conv5_block28_2_conv
# 564 - conv5_block28_concat
# 565 - conv5_block29_0_bn
# 566 - conv5_block29_0_relu
# 567 - conv5_block29_1_conv
# 568 - conv5_block29_1_bn
# 569 - conv5_block29_1_relu
# 570 - conv5_block29_2_conv
# 571 - conv5_block29_concat
# 572 - conv5_block30_0_bn
# 573 - conv5_block30_0_relu
# 574 - conv5_block30_1_conv
# 575 - conv5_block30_1_bn
# 576 - conv5_block30_1_relu
# 577 - conv5_block30_2_conv
# 578 - conv5_block30_concat
# 579 - conv5_block31_0_bn
# 580 - conv5_block31_0_relu
# 581 - conv5_block31_1_conv
# 582 - conv5_block31_1_bn
# 583 - conv5_block31_1_relu
# 584 - conv5_block31_2_conv
# 585 - conv5_block31_concat
# 586 - conv5_block32_0_bn
# 587 - conv5_block32_0_relu
# 588 - conv5_block32_1_conv
# 589 - conv5_block32_1_bn
# 590 - conv5_block32_1_relu
# 591 - conv5_block32_2_conv
# 592 - conv5_block32_concat
# 593 - bn
# 594 - relu

# %%
# Define the input shape
input_shape = (512, 512, 3)

# Define the number of classes
num_classes = 3

# Freeze the layers in the base model
pretrained_model.trainable = True

freeze_layer_limit = 367

# Freeze first layers
for i, layer in enumerate(pretrained_model.layers[:freeze_layer_limit]):
    layer.trainable=False

# Data Augmentation layers
inputs = keras.layers.Input((512,512,1))

x = keras.layers.RandomBrightness(0.11)(inputs)
x = keras.layers.RandomZoom(0.21, fill_mode='constant', interpolation='bilinear',fill_value=0.0)(x)
x = keras.layers.RandomContrast(0.105)(x)
x = keras.layers.RandomRotation(0.5, fill_mode='constant', interpolation='bilinear',fill_value=0.0)(x)
x = keras.layers.RandomTranslation(0.12, 0.15, fill_mode='constant', interpolation='bilinear',fill_value=0.0)(x)
x = keras.layers.GaussianNoise(stddev=1.0)(x)
x = keras.layers.Reshape((512,512,1))(x)
x = keras.layers.concatenate([x for i in range(3)],axis=-1)
x = keras.layers.Lambda(function=keras.applications.densenet.preprocess_input, output_shape=(512,512,3))(x)




x = pretrained_model(x)
    
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.35)(x)
x = keras.layers.Dense(units = 256, activation='relu')(x)
outputs = keras.layers.Dense(num_classes, activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
# Compile the model
model.compile(loss=tfa.losses.SigmoidFocalCrossEntropy(), optimizer=tfa.optimizers.Yogi(1e-4), metrics='accuracy')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  random_brightness (RandomBrigh  (None, 512, 512, 1)  0          ['input_2[0][0]']
#  tness)
#
#  random_zoom (RandomZoom)       (None, 512, 512, 1)  0           ['random_brightness[0][0]']
#
#  random_contrast (RandomContras  (None, 512, 512, 1)  0          ['random_zoom[0][0]']
#  t)
#
#  random_rotation (RandomRotatio  (None, 512, 512, 1)  0          ['random_contrast[0][0]']
#  n)
#
#  random_translation (RandomTran  (None, 512, 512, 1)  0          ['random_rotation[0][0]']
#  slation)
#
#  gaussian_noise (GaussianNoise)  (None, 512, 512, 1)  0          ['random_translation[0][0]']
#
#  reshape (Reshape)              (None, 512, 512, 1)  0           ['gaussian_noise[0][0]']
#
#  concatenate (Concatenate)      (None, 512, 512, 3)  0           ['reshape[0][0]',
#                                                                   'reshape[0][0]',
#                                                                   'reshape[0][0]']
#
#  lambda (Lambda)                (None, 512, 512, 3)  0           ['concatenate[0][0]']
#
#  densenet169 (Functional)       (None, 16, 16, 1664  12642880    ['lambda[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1664)        0           ['densenet169[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1664)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 256)          426240      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 3)            771         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 13,069,891
# Trainable params: 7,163,139
# Non-trainable params: 5,906,752
# __________________________________________________________________________________________________

# %%
history_model = model.fit(
    x = train_generator,
    batch_size = 64,
    epochs = 35,
    validation_data = validation_generator,
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, min_lr=1e-6)
                ]
).history
# Out:
# Epoch 1/35
# 122/122 [==============================] - 478s 3s/step - loss: 0.1056 - accuracy: 0.8010 - val_loss: 0.0542 - val_accuracy: 0.8947 - lr: 1.0000e-04
# Epoch 2/35
# 122/122 [==============================] - 409s 3s/step - loss: 0.0656 - accuracy: 0.8867 - val_loss: 0.0424 - val_accuracy: 0.9329 - lr: 1.0000e-04
# Epoch 3/35
# 122/122 [==============================] - 408s 3s/step - loss: 0.0548 - accuracy: 0.9029 - val_loss: 0.0357 - val_accuracy: 0.9479 - lr: 1.0000e-04
# Epoch 4/35
# 122/122 [==============================] - 411s 3s/step - loss: 0.0502 - accuracy: 0.9140 - val_loss: 0.0383 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 5/35
# 122/122 [==============================] - 409s 3s/step - loss: 0.0448 - accuracy: 0.9220 - val_loss: 0.0940 - val_accuracy: 0.8634 - lr: 1.0000e-04
# Epoch 6/35
# 122/122 [==============================] - 411s 3s/step - loss: 0.0443 - accuracy: 0.9238 - val_loss: 0.0452 - val_accuracy: 0.9132 - lr: 1.0000e-04
# Epoch 7/35
# 122/122 [==============================] - 413s 3s/step - loss: 0.0404 - accuracy: 0.9349 - val_loss: 0.0343 - val_accuracy: 0.9444 - lr: 1.0000e-04
# Epoch 8/35
# 122/122 [==============================] - 411s 3s/step - loss: 0.0359 - accuracy: 0.9417 - val_loss: 0.0361 - val_accuracy: 0.9387 - lr: 1.0000e-04
# Epoch 9/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0340 - accuracy: 0.9432 - val_loss: 0.0405 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 10/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0326 - accuracy: 0.9462 - val_loss: 0.0297 - val_accuracy: 0.9537 - lr: 1.0000e-04
# Epoch 11/35
# 122/122 [==============================] - 408s 3s/step - loss: 0.0316 - accuracy: 0.9456 - val_loss: 0.0299 - val_accuracy: 0.9456 - lr: 1.0000e-04
# Epoch 12/35
# 122/122 [==============================] - 409s 3s/step - loss: 0.0293 - accuracy: 0.9513 - val_loss: 0.0464 - val_accuracy: 0.9306 - lr: 1.0000e-04
# Epoch 13/35
# 122/122 [==============================] - 409s 3s/step - loss: 0.0285 - accuracy: 0.9535 - val_loss: 0.0439 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 14/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0287 - accuracy: 0.9534 - val_loss: 0.0293 - val_accuracy: 0.9572 - lr: 1.0000e-04
# Epoch 15/35
# 122/122 [==============================] - 412s 3s/step - loss: 0.0264 - accuracy: 0.9538 - val_loss: 0.0359 - val_accuracy: 0.9421 - lr: 1.0000e-04
# Epoch 16/35
# 122/122 [==============================] - 411s 3s/step - loss: 0.0244 - accuracy: 0.9600 - val_loss: 0.0264 - val_accuracy: 0.9491 - lr: 1.0000e-04
# Epoch 17/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0245 - accuracy: 0.9602 - val_loss: 0.0277 - val_accuracy: 0.9572 - lr: 1.0000e-04
# Epoch 18/35
# 122/122 [==============================] - 408s 3s/step - loss: 0.0225 - accuracy: 0.9634 - val_loss: 0.0290 - val_accuracy: 0.9525 - lr: 1.0000e-04
# Epoch 19/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0238 - accuracy: 0.9625 - val_loss: 0.0341 - val_accuracy: 0.9456 - lr: 1.0000e-04
# Epoch 20/35
# 122/122 [==============================] - 410s 3s/step - loss: 0.0213 - accuracy: 0.9660 - val_loss: 0.0276 - val_accuracy: 0.9525 - lr: 1.0000e-04
# Epoch 21/35
# 122/122 [==============================] - 412s 3s/step - loss: 0.0194 - accuracy: 0.9686 - val_loss: 0.0583 - val_accuracy: 0.9248 - lr: 1.0000e-04

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history_model['loss'], label='Training Loss', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_model['val_loss'], label='Validation Loss', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history_model['accuracy'], label = 'Training Accuracy', alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_model['val_accuracy'], label='Validation Accuracy', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
print("hi")

# %%
# Predict the test set with the CNN1
predictions = model.predict(test_generator)
label_names = {
    0: "N",
    1: "P",
    2: "T"
}
label_classes = label_names.values()
converted_test_labels = np.zeros(test_path_based["label"].shape)
converted_test_labels[test_path_based["label"] == 'N'] = 0
converted_test_labels[test_path_based["label"] == 'P'] = 1
converted_test_labels[test_path_based["label"] == 'T'] = 2
# Out:
# 34/34 [==============================] - 64s 2s/step

# %%
prediction_numerical = np.argmax(predictions, axis=-1)

# %%
# Compute the confusion matrix
cm = confusion_matrix(converted_test_labels, np.argmax(predictions, axis=-1))
cm_rel = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Compute the classification metrics
accuracy = accuracy_score(converted_test_labels, np.argmax(predictions, axis=-1))
precision = precision_score(converted_test_labels, np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(converted_test_labels, np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(converted_test_labels, np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_rel.T, xticklabels=label_classes, yticklabels=label_classes, annot=True, fmt='.2f')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.9565
# Precision: 0.9525
# Recall: 0.9245
# F1: 0.9377

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
from sklearn.metrics import classification_report
# generate the classification report
print(classification_report(converted_test_labels, prediction_numerical, target_names=['Normal', 'Pneumonia', 'Tuberculosis']))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.98      0.97      1319
#    Pneumonia       0.99      0.95      0.97       577
# Tuberculosis       0.92      0.84      0.88       263
#
#     accuracy                           0.96      2159
#    macro avg       0.95      0.92      0.94      2159
# weighted avg       0.96      0.96      0.96      2159

# %% [markdown]
# Apparently, there is a bug with tensorflow versions >= 2.10.0 Efficientnet networks cannot be serialized. I need to retrain the model with tensorflow 2.9.0 to be able to export it.

# %%
model.save('DenseNet169-withAug')

# %%
# !zip -r DenseNet169-withAug.zip DenseNet169-withAug -r
# Out:
#   adding: DenseNet169-withAug/ (stored 0%)
#   adding: DenseNet169-withAug/keras_metadata.pb (deflated 96%)
#   adding: DenseNet169-withAug/variables/ (stored 0%)
#   adding: DenseNet169-withAug/variables/variables.data-00000-of-00001 (deflated 15%)
#   adding: DenseNet169-withAug/variables/variables.index (deflated 80%)
#   adding: DenseNet169-withAug/assets/ (stored 0%)
#   adding: DenseNet169-withAug/saved_model.pb (deflated 92%)
#   adding: DenseNet169-withAug/fingerprint.pb (stored 0%)

# %%
x = pretrained_model.output
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.35)(x)
x = keras.layers.Dense(units = 256, activation='relu')(x)
outputs = keras.layers.Dense(3, activation="softmax")(x)
model_complete = keras.Model(pretrained_model.input, outputs)

model_complete.set_weights(model.get_weights())
model_complete.compile(loss=tfa.losses.SigmoidFocalCrossEntropy(), optimizer=tfa.optimizers.Yogi(1e-4), metrics='accuracy')
model_complete.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 518, 518, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 256, 256, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 256, 256, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 258, 258, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 128, 128, 64  0           ['zero_padding2d_1[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 64  256        ['pool1[0][0]']
#  ization)                       )
#
#  conv2_block1_0_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_0_bn[0][0]']
#  n)                             )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 12  8192        ['conv2_block1_0_relu[0][0]']
#                                 8)
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_concat (Concatena  (None, 128, 128, 96  0          ['pool1[0][0]',
#  te)                            )                                 'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 128, 128, 96  384        ['conv2_block1_concat[0][0]']
#  ization)                       )
#
#  conv2_block2_0_relu (Activatio  (None, 128, 128, 96  0          ['conv2_block2_0_bn[0][0]']
#  n)                             )
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 12  12288       ['conv2_block2_0_relu[0][0]']
#                                 8)
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_concat (Concatena  (None, 128, 128, 12  0          ['conv2_block1_concat[0][0]',
#  te)                            8)                                'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_concat[0][0]']
#  ization)                       8)
#
#  conv2_block3_0_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_0_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 12  16384       ['conv2_block3_0_relu[0][0]']
#                                 8)
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_concat (Concatena  (None, 128, 128, 16  0          ['conv2_block2_concat[0][0]',
#  te)                            0)                                'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 128, 128, 16  640        ['conv2_block3_concat[0][0]']
#  ization)                       0)
#
#  conv2_block4_0_relu (Activatio  (None, 128, 128, 16  0          ['conv2_block4_0_bn[0][0]']
#  n)                             0)
#
#  conv2_block4_1_conv (Conv2D)   (None, 128, 128, 12  20480       ['conv2_block4_0_relu[0][0]']
#                                 8)
#
#  conv2_block4_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block4_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block4_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block4_1_relu[0][0]']
#                                 )
#
#  conv2_block4_concat (Concatena  (None, 128, 128, 19  0          ['conv2_block3_concat[0][0]',
#  te)                            2)                                'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 128, 128, 19  768        ['conv2_block4_concat[0][0]']
#  ization)                       2)
#
#  conv2_block5_0_relu (Activatio  (None, 128, 128, 19  0          ['conv2_block5_0_bn[0][0]']
#  n)                             2)
#
#  conv2_block5_1_conv (Conv2D)   (None, 128, 128, 12  24576       ['conv2_block5_0_relu[0][0]']
#                                 8)
#
#  conv2_block5_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block5_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block5_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block5_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block5_1_relu[0][0]']
#                                 )
#
#  conv2_block5_concat (Concatena  (None, 128, 128, 22  0          ['conv2_block4_concat[0][0]',
#  te)                            4)                                'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 128, 128, 22  896        ['conv2_block5_concat[0][0]']
#  ization)                       4)
#
#  conv2_block6_0_relu (Activatio  (None, 128, 128, 22  0          ['conv2_block6_0_bn[0][0]']
#  n)                             4)
#
#  conv2_block6_1_conv (Conv2D)   (None, 128, 128, 12  28672       ['conv2_block6_0_relu[0][0]']
#                                 8)
#
#  conv2_block6_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block6_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block6_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block6_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block6_1_relu[0][0]']
#                                 )
#
#  conv2_block6_concat (Concatena  (None, 128, 128, 25  0          ['conv2_block5_concat[0][0]',
#  te)                            6)                                'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 128, 128, 25  1024        ['conv2_block6_concat[0][0]']
#                                 6)
#
#  pool2_relu (Activation)        (None, 128, 128, 25  0           ['pool2_bn[0][0]']
#                                 6)
#
#  pool2_conv (Conv2D)            (None, 128, 128, 12  32768       ['pool2_relu[0][0]']
#                                 8)
#
#  pool2_pool (AveragePooling2D)  (None, 64, 64, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 64, 64, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 64, 64, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 64, 64, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 64, 64, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 64, 64, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 64, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 64, 64, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 64, 64, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 64, 64, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 64, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 64, 64, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 64, 64, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 64, 64, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 64, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 64, 64, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 64, 64, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 64, 64, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 64, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 64, 64, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 64, 64, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 64, 64, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 64, 64, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 64, 64, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 64, 64, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 64, 64, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 64, 64, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 64, 64, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 64, 64, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 64, 64, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 64, 64, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 64, 64, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 64, 64, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 64, 64, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 64, 64, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 64, 64, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 64, 64, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 64, 64, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 64, 64, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 32, 32, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 32, 32, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 32, 32, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 32, 32, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 32, 32, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block5_1_bn[0][0]']
# ...
#
#  conv5_block25_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 16, 16, 1440  0          ['conv5_block24_concat[0][0]',
#  ate)                           )                                 'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 16, 16, 1440  5760       ['conv5_block25_concat[0][0]']
#  lization)                      )
#
#  conv5_block26_0_relu (Activati  (None, 16, 16, 1440  0          ['conv5_block26_0_bn[0][0]']
#  on)                            )
#
#  conv5_block26_1_conv (Conv2D)  (None, 16, 16, 128)  184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 16, 16, 1472  0          ['conv5_block25_concat[0][0]',
#  ate)                           )                                 'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 16, 16, 1472  5888       ['conv5_block26_concat[0][0]']
#  lization)                      )
#
#  conv5_block27_0_relu (Activati  (None, 16, 16, 1472  0          ['conv5_block27_0_bn[0][0]']
#  on)                            )
#
#  conv5_block27_1_conv (Conv2D)  (None, 16, 16, 128)  188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 16, 16, 1504  0          ['conv5_block26_concat[0][0]',
#  ate)                           )                                 'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 16, 16, 1504  6016       ['conv5_block27_concat[0][0]']
#  lization)                      )
#
#  conv5_block28_0_relu (Activati  (None, 16, 16, 1504  0          ['conv5_block28_0_bn[0][0]']
#  on)                            )
#
#  conv5_block28_1_conv (Conv2D)  (None, 16, 16, 128)  192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 16, 16, 1536  0          ['conv5_block27_concat[0][0]',
#  ate)                           )                                 'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 16, 16, 1536  6144       ['conv5_block28_concat[0][0]']
#  lization)                      )
#
#  conv5_block29_0_relu (Activati  (None, 16, 16, 1536  0          ['conv5_block29_0_bn[0][0]']
#  on)                            )
#
#  conv5_block29_1_conv (Conv2D)  (None, 16, 16, 128)  196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 16, 16, 1568  0          ['conv5_block28_concat[0][0]',
#  ate)                           )                                 'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 16, 16, 1568  6272       ['conv5_block29_concat[0][0]']
#  lization)                      )
#
#  conv5_block30_0_relu (Activati  (None, 16, 16, 1568  0          ['conv5_block30_0_bn[0][0]']
#  on)                            )
#
#  conv5_block30_1_conv (Conv2D)  (None, 16, 16, 128)  200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 16, 16, 1600  0          ['conv5_block29_concat[0][0]',
#  ate)                           )                                 'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 16, 16, 1600  6400       ['conv5_block30_concat[0][0]']
#  lization)                      )
#
#  conv5_block31_0_relu (Activati  (None, 16, 16, 1600  0          ['conv5_block31_0_bn[0][0]']
#  on)                            )
#
#  conv5_block31_1_conv (Conv2D)  (None, 16, 16, 128)  204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 16, 16, 1632  0          ['conv5_block30_concat[0][0]',
#  ate)                           )                                 'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 16, 16, 1632  6528       ['conv5_block31_concat[0][0]']
#  lization)                      )
#
#  conv5_block32_0_relu (Activati  (None, 16, 16, 1632  0          ['conv5_block32_0_bn[0][0]']
#  on)                            )
#
#  conv5_block32_1_conv (Conv2D)  (None, 16, 16, 128)  208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 16, 16, 128)  0          ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 16, 16, 1664  0          ['conv5_block31_concat[0][0]',
#  ate)                           )                                 'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 16, 16, 1664  6656        ['conv5_block32_concat[0][0]']
#                                 )
#
#  relu (Activation)              (None, 16, 16, 1664  0           ['bn[0][0]']
#                                 )
#
#  global_average_pooling2d_2 (Gl  (None, 1664)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  dropout_2 (Dropout)            (None, 1664)         0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 256)          426240      ['dropout_2[0][0]']
#
#  dense_5 (Dense)                (None, 3)            771         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 13,069,891
# Trainable params: 7,163,139
# Non-trainable params: 5,906,752
# __________________________________________________________________________________________________

# %%
model_complete.save('DenseNet169-withAug_expanded')

# %%
# !zip -r DenseNet169-withAug_expanded.zip /kaggle/working/DenseNet169-withAug_expanded -r
# Out:
#   adding: kaggle/working/DenseNet169-withAug_expanded/ (stored 0%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/keras_metadata.pb (deflated 96%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/variables/ (stored 0%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/variables/variables.index (deflated 81%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/assets/ (stored 0%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/saved_model.pb (deflated 93%)
#   adding: kaggle/working/DenseNet169-withAug_expanded/fingerprint.pb (stored 0%)
